# %% [markdown]
# # Code to extract numbers from picture

# %%
import matplotlib.pyplot as plt
#pip install keras_ocr
# %pip install numpy
import keras_ocr
import os
# Out:
# Requirement already satisfied: keras_ocr in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (0.8.9)
# Requirement already satisfied: editdistance in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (0.6.0)
# Requirement already satisfied: shapely in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (1.8.1.post1)
# Requirement already satisfied: validators in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (0.18.2)
# Requirement already satisfied: pyclipper in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (1.3.0.post2)
# Requirement already satisfied: fonttools in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (4.32.0)
# Requirement already satisfied: imgaug in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (0.4.0)
# Requirement already satisfied: efficientnet==1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (1.0)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras_ocr) (4.63.0)
# Requirement already satisfied: scikit-image in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from efficientnet==1.0.0->keras_ocr) (0.19.2)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from efficientnet==1.0.0->keras_ocr) (1.0.8)
# Requirement already satisfied: imageio in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (2.16.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (3.4.2)
# Requirement already satisfied: Pillow in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (9.0.1)
# Requirement already satisfied: numpy>=1.15 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (1.22.3)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (1.7.3)
# Requirement already satisfied: opencv-python in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (4.5.5.64)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from imgaug->keras_ocr) (1.15.0)
# Requirement already satisfied: decorator>=3.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from validators->keras_ocr) (5.1.1)
# Requirement already satisfied: h5py in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (3.1.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2022.4.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (21.3)
# Requirement already satisfied: networkx>=2.2 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->imgaug->keras_ocr) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->imgaug->keras_ocr) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->imgaug->keras_ocr) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->imgaug->keras_ocr) (0.11.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /Users/marcofking/.keras-ocr/craft_mlt_25k.h5
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000002?line=0'>1</a> # keras-ocr will automatically download pretrained
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000002?line=1'>2</a> # weights for the detector and recognizer.
# ----> <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000002?line=2'>3</a> pipeline = keras_ocr.pipeline.Pipeline()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py:22, in Pipeline.__init__(self, detector, recognizer, scale, max_size)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py?line=19'>20</a>     detector = detection.Detector()
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py?line=20'>21</a> if recognizer is None:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py?line=21'>22</a>     recognizer = recognition.Recognizer()
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py?line=22'>23</a> self.scale = scale
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/pipeline.py?line=23'>24</a> self.detector = detector
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py:388, in Recognizer.__init__(self, alphabet, weights, build_params)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=380'>381</a> self.alphabet = alphabet
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=381'>382</a> self.blank_label_idx = len(alphabet)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=382'>383</a> (
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=383'>384</a>     self.backbone,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=384'>385</a>     self.model,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=385'>386</a>     self.training_model,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=386'>387</a>     self.prediction_model,
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=387'>388</a> ) = build_model(alphabet=alphabet, **build_params)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=388'>389</a> if weights is not None:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=389'>390</a>     weights_dict = PRETRAINED_WEIGHTS[weights]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py:285, in build_model(alphabet, height, width, color, filters, rnn_units, dropout, rnn_steps_to_discard, pool_size, stn)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=276'>277</a>     locnet_y = keras.layers.Dense(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=277'>278</a>         6,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=278'>279</a>         weights=[
#    (...)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=281'>282</a>         ],
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=282'>283</a>     )(locnet_y)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=283'>284</a>     localization_net = keras.models.Model(inputs=stn_input_layer, outputs=locnet_y)
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=284'>285</a>     x = keras.layers.Lambda(_transform, output_shape=stn_input_output_shape)(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=285'>286</a>         [x, localization_net(x)]
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=286'>287</a>     )
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=287'>288</a> x = keras.layers.Reshape(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=288'>289</a>     target_shape=(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=289'>290</a>         width // pool_size ** 2,
#    (...)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=292'>293</a>     name="reshape",
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=293'>294</a> )(x)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=295'>296</a> x = keras.layers.Dense(rnn_units[0], activation="relu", name="fc_9")(x)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:969, in Layer.__call__(self, *args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=962'>963</a> # Functional Model construction mode is invoked when `Layer`s are called on
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=963'>964</a> # symbolic `KerasTensor`s, i.e.:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=964'>965</a> # >> inputs = tf.keras.Input(10)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=965'>966</a> # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=966'>967</a> # >> model = tf.keras.Model(inputs, outputs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=967'>968</a> if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=968'>969</a>   return self._functional_construction_call(inputs, args, kwargs,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=969'>970</a>                                             input_list)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=971'>972</a> # Maintains info about the `Layer.call` stack.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=972'>973</a> call_context = base_layer_utils.call_context()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1107, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1101'>1102</a>     training_arg_passed_by_framework = True
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1103'>1104</a> with call_context.enter(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1104'>1105</a>     layer=self, inputs=inputs, build_graph=True, training=training_value):
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1105'>1106</a>   # Check input assumptions set after layer building, e.g. input shape.
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1106'>1107</a>   outputs = self._keras_tensor_symbolic_call(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1107'>1108</a>       inputs, input_masks, args, kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1109'>1110</a>   if outputs is None:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1110'>1111</a>     raise ValueError('A layer\'s `call` method should return a '
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1111'>1112</a>                      'Tensor or a list of Tensors, not None '
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1112'>1113</a>                      '(layer: ' + self.name + ').')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:840, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=837'>838</a>   return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=838'>839</a> else:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=839'>840</a>   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:880, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=877'>878</a>     self._maybe_build(inputs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=878'>879</a>     inputs = self._maybe_cast_inputs(inputs)
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=879'>880</a>     outputs = call_fn(inputs, *args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=881'>882</a>   self._handle_activity_regularization(inputs, outputs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=882'>883</a> self._set_mask_metadata(inputs, outputs, input_masks,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py?line=883'>884</a>                         build_graph=False)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py:919, in Lambda.call(self, inputs, mask, training)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=914'>915</a>   return var
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=916'>917</a> with backprop.GradientTape(watch_accessed_variables=True) as tape,\
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=917'>918</a>     variable_scope.variable_creator_scope(_variable_creator):
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=918'>919</a>   result = self.function(inputs, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=919'>920</a> self._check_variables(created_variables, tape.watched_variables())
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py?line=920'>921</a> return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py:88, in _transform(inputs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=85'>86</a> output_height = output_size[0]
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=86'>87</a> output_width = output_size[1]
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=87'>88</a> indices_grid = _meshgrid(output_height, output_width)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=88'>89</a> indices_grid = tf.expand_dims(indices_grid, 0)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=89'>90</a> indices_grid = tf.reshape(indices_grid, [-1])  # flatten?
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py:64, in _meshgrid(height, width)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=61'>62</a> x_linspace = tf.linspace(-1.0, 1.0, width)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=62'>63</a> y_linspace = tf.linspace(-1.0, 1.0, height)
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=63'>64</a> x_coordinates, y_coordinates = tf.meshgrid(x_linspace, y_linspace)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=64'>65</a> x_coordinates = tf.reshape(x_coordinates, shape=(1, -1))
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/recognition.py?line=65'>66</a> y_coordinates = tf.reshape(y_coordinates, shape=(1, -1))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=203'>204</a> """Call target, and fall back on dispatchers if there is a TypeError."""
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=204'>205</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=205'>206</a>   return target(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=206'>207</a> except (TypeError, ValueError):
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=207'>208</a>   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=208'>209</a>   # TypeError, when given unexpected types.  So we need to catch both.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=209'>210</a>   result = dispatch(wrapper, args, kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:3644, in meshgrid(*args, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3640'>3641</a>   shapes[0], shapes[1] = shapes[1], shapes[0]
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3642'>3643</a> # TODO(nolivia): improve performance with a broadcast
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3643'>3644</a> mult_fact = ones(shapes, output_dtype)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3644'>3645</a> return [x * mult_fact for x in output]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=203'>204</a> """Call target, and fall back on dispatchers if there is a TypeError."""
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=204'>205</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=205'>206</a>   return target(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=206'>207</a> except (TypeError, ValueError):
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=207'>208</a>   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=208'>209</a>   # TypeError, when given unexpected types.  So we need to catch both.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py?line=209'>210</a>   result = dispatch(wrapper, args, kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:3212, in ones(shape, dtype, name)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3207'>3208</a> try:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3208'>3209</a>   if not context.executing_eagerly():
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3209'>3210</a>     # Create a constant if it won't be very big. Otherwise create a fill
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3210'>3211</a>     # op to prevent serialized GraphDefs from becoming too large.
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3211'>3212</a>     output = _constant_if_small(one, shape, dtype, name)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3212'>3213</a>     if output is not None:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=3213'>3214</a>       return output
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:2896, in _constant_if_small(value, shape, dtype, name)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2893'>2894</a> def _constant_if_small(value, shape, dtype, name):
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2894'>2895</a>   try:
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2895'>2896</a>     if np.prod(shape) < 1000:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2896'>2897</a>       return constant(value, shape=shape, dtype=dtype, name=name)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2897'>2898</a>   except TypeError:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py?line=2898'>2899</a>     # Happens when shape is a Tensor, list with Tensor elements, etc.
#
# File <__array_function__ internals>:180, in prod(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3088, in prod(a, axis, dtype, out, keepdims, initial, where)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2969'>2970</a> @array_function_dispatch(_prod_dispatcher)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2970'>2971</a> def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2971'>2972</a>          initial=np._NoValue, where=np._NoValue):
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2972'>2973</a>     """
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2973'>2974</a>     Return the product of array elements over a given axis.
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2974'>2975</a>
#    (...)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=3085'>3086</a>     10
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=3086'>3087</a>     """
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=3087'>3088</a>     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=3088'>3089</a>                           keepdims=keepdims, initial=initial, where=where)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=82'>83</a>         else:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=83'>84</a>             return reduction(axis=axis, out=out, **passkwargs)
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=85'>86</a> return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:867, in Tensor.__array__(self)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py?line=865'>866</a> def __array__(self):
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py?line=866'>867</a>   raise NotImplementedError(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py?line=867'>868</a>       "Cannot convert a symbolic Tensor ({}) to a numpy array."
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py?line=868'>869</a>       " This error may indicate that you're trying to pass a Tensor to"
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/framework/ops.py?line=869'>870</a>       " a NumPy call, which is not supported".format(self.name))
#
# NotImplementedError: Cannot convert a symbolic Tensor (lambda_5/meshgrid/Size_1:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %%
print(os.getcwd())
# Get a set of three example images
images = [
    keras_ocr.tools.read(images) for images in [
        #'/just_number.png',
        'images/NdHYc.jpg'
    ]
]
# Out:
# /Users/marcofking/Documents/GitHub/yi_contact_expt/src
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=0'>1</a> print(os.getcwd())
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=1'>2</a> # Get a set of three example images
# ----> <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=2'>3</a> images = [
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=3'>4</a>     keras_ocr.tools.read(images) for images in [
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=4'>5</a>         #'/just_number.png',
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=5'>6</a>         'images/NdHYc.jpg'
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=6'>7</a>     ]
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=7'>8</a> ]
#
# /Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb Cell 5' in <listcomp>(.0)
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=0'>1</a> print(os.getcwd())
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=1'>2</a> # Get a set of three example images
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=2'>3</a> images = [
# ----> <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=3'>4</a>     keras_ocr.tools.read(images) for images in [
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=4'>5</a>         #'/just_number.png',
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=5'>6</a>         'images/NdHYc.jpg'
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=6'>7</a>     ]
#       <a href='vscode-notebook-cell:/Users/marcofking/Documents/GitHub/yi_contact_expt/src/yi_image_analyis_JN.ipynb#ch0000003?line=7'>8</a> ]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py:34, in read(filepath_or_buffer)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=31'>32</a>     if validators.url(filepath_or_buffer):
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=32'>33</a>         return read(urllib.request.urlopen(filepath_or_buffer))
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=33'>34</a>     assert os.path.isfile(filepath_or_buffer), (
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=34'>35</a>         "Could not find image at path: " + filepath_or_buffer
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=35'>36</a>     )
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=36'>37</a>     image = cv2.imread(filepath_or_buffer)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/keras_ocr/tools.py?line=37'>38</a> return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#
# AssertionError: Could not find image at path: images/NdHYc.jpg

# %%
# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# %%
print(prediction_groups)

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
